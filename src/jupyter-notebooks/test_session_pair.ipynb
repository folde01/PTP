# %%
from ptp_analyser import Analyser
from scapy.all import *
analyser = Analyser(existing_pcap_filename='../test-pcap-files/ssl-test.pcap')

# %%
sr = analyser._get_session_reassembler()

# %%
sr.get_session_pairs()
# Out:
# {('10.0.2.15',
#   '33074',
#   '216.58.206.33',
#   '80'): <ptp_session_pair.Session_Pair at 0x7f23feeef7d0>,
#  ('10.0.2.15',
#   '37547',
#   '216.58.206.46',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeefa10>,
#  ('10.0.2.15',
#   '37548',
#   '216.58.206.46',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef650>,
#  ('10.0.2.15',
#   '37549',
#   '216.58.206.46',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef4d0>,
#  ('10.0.2.15',
#   '37550',
#   '216.58.206.46',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef890>,
#  ('10.0.2.15',
#   '37551',
#   '216.58.206.46',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef950>,
#  ('10.0.2.15',
#   '47768',
#   '52.95.132.37',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef350>,
#  ('10.0.2.15',
#   '47769',
#   '52.95.132.37',
#   '443'): <ptp_session_pair.Session_Pair at 0x7f23feeef410>,
#  ('10.0.2.15',
#   '48763',
#   '2.16.57.56',
# ...

# %%
sr.get_session_pairs()[('10.0.2.15',
  '55083',
  '104.25.157.13',
  '443')]

# %%
pair_where_ssl_cli_hello_is_seen = sr.get_session_pairs()[('10.0.2.15',
  '55083',
  '104.25.157.13',
  '443')]

# %%
dir(pair_where_ssl_cli_hello_is_seen)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cli_to_svr',
#  '_const',
#  '_get_load',
#  '_get_pkt_payload_length',
#  '_get_session_payload_size',
#  '_get_ssl_status',
#  '_get_start_and_end_ts',
#  '_get_tcp_status',
#  '_is_encrypted',
#  '_packet_has_payload',
#  '_ssl_handshake_analysis_old',
#  '_ssl_handshake_client_analysis',
#  '_ssl_handshake_server_analysis',
#  '_ssl_status',
#  '_ssl_tunnel_analysis',
#  '_stream_status',
#  '_svr_to_cli',
#  '_tcp_close_analysis',
#  '_tcp_handshake_is_seen',
#  '_tcp_status',
#  'get_stream_status']

# %%
dir(pair_where_ssl_cli_hello_is_seen._ssl_status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'get_ssl_tuple',
#  'is_encrypted',
#  'set_client_hello',
#  'show',
#  'ssl_cipher',
#  'ssl_cli_ccs',
#  'ssl_cli_hello',
#  'ssl_svr_ccs',
#  'ssl_svr_hello',
#  'ssl_version']

# %%
pair_where_ssl_cli_hello_is_seen._ssl_status.ssl_cli_hello
# Out:
# False

# %%
pair_where_ssl_cli_hello_is_seen._ssl_status.ssl_svr_hello
# Out:
# False

# %%
pair_where_ssl_cli_hello_is_seen._ssl_status.show()
# Out:
# ssl_cli_hello: False
# ssl_cli_ccs: False
# ssl_svr_hello: False
# ssl_version: NO VERSION
# ssl_cipher: NO CIPHER
# ssl_svr_ccs: False
# is_encrypted: Unassessed

# %%
pair = pair_where_ssl_cli_hello_is_seen
for pkt in pair._cli_to_svr:
    if pkt.haslayer(Raw):
        print pair._get_load(pkt), "\n"
# Out:
# ...
#
# 16030300251000002120a23f91a525a93d013411f9bcdb212a287e479b124374d564eb50740257af402f140303000101160303002026133bbc8929313b25af9f15cd80d6c16a7a7b53c429aa488aa140e1751b06b9
#
# 170303002834a7b3af08f0ec0476c4586acfdf61536ca6436a0bf9a75b33b6b444b1b9eb1b6e86905a867bcb9f
#
# 170303002579ac866f3383e911a02474a89bebad55d00e1273b1fa04f3fcc434f2c04a668e536f636f01
#
# 170303001d5f4fa55ed26d65d7f0d4037aaf9f59dd5e8e9aaba2d1f79128c0678428
#
# 1703030019571413ed24d9d0550619090ed8c822378136dfb13b5881525b
#
# ...

# %%
pair._ssl_handshake_client_analysis()
# Out:
# num_pkts_with_payload: 7
# pkt_seq_load: ...
# match: <_sre.SRE_Match object at 0x7f23fed6a580>
# groups: ('16030100ca01', '140303000101')
# client_hello_seen: True
# client_ccs_seen: True
# ssl_status.show(): ssl_cli_hello: True
# ssl_cli_ccs: True
# ssl_svr_hello: False
# ssl_version: NO VERSION
# ssl_cipher: NO CIPHER
# ssl_svr_ccs: False
# is_encrypted: Unassessed
#
# None

# %%
pair._ssl_handshake_server_analysis()
# Out:
# pkt_seq_load: ...
# groups: ('160303004c', '0200004803035b8ee63ce442bc63b0959d0bbe7aac71ae0400752d0cc350444f574e4752440100', '0303', '00')
# groups: ('160303004c', '0200004803035b8ee63ce442bc63b0959d0bbe7aac71ae0400752d0cc350444f574e4752440100', '0303', '00', 'cca9', '...', '140303000101', '1603030020')
# ssl_status.show(): ssl_cli_hello: True
# ssl_cli_ccs: True
# ssl_svr_hello: True
# ssl_version: TLS 1.2
# ssl_cipher: TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256
# ssl_svr_ccs: True
# is_encrypted: Unassessed
#
# None

# %%
pair._get_tcp_status()

# %%
pair._is_encrypted()

# %%
pair._ssl_status.show()
# Out:
# ssl_cli_hello: True
# ssl_cli_ccs: True
# ssl_svr_hello: True
# ssl_version: TLS 1.2
# ssl_cipher: TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256
# ssl_svr_ccs: True
# is_encrypted: Yes
